# %%
import os
import time
import json
import pandas as pd
from openai import OpenAI
from transformers import AutoTokenizer
from get_params import DATA_FOLDER, SHARED_DATA_FOLDER, TEST_DATASET_BASE_FPATH, TEST_DATASET_FT_FPATH

## Get OpenAI Key
with open(os.path.join(DATA_FOLDER, "openai_key.txt")) as f:
    OPENAI_KEY = f.read().strip()


## Get HF tokenizer
with open(os.path.join(DATA_FOLDER, "hftoken.txt")) as f:
    HF_TOKEN = f.read().strip()


MODEL_NAME = "gpt-4o"
MODEL_TEMPERATURE = 0.0 # we want variety for this task

# %%
test_base_model_df = pd.read_json(TEST_DATASET_BASE_FPATH, lines=True)
test_base_model_df = test_base_model_df.rename(columns={"ai_answer": "mistralinstruct_answer"})
test_tuned_model_df = pd.read_json(TEST_DATASET_FT_FPATH, lines=True)
test_tuned_model_df = test_tuned_model_df.rename(columns={"ai_answer": "pretendparentai_answer"})

test_all_df = test_tuned_model_df.merge(test_base_model_df[["id", "mistralinstruct_answer"]], how="inner", on="id")

# %%
test_all_df.head(2)
# Out:
#    id                                               text  \
# 0   1  Dealing with Emotional Outbursts - Our 10-year...
# 1   2  Teenager Afraid of the Dark: Is This Normal? -...
#
#                                           title  \
# 0              Dealing with Emotional Outbursts
# 1  Teenager Afraid of the Dark: Is This Normal?
#
#                                                 body  prompt_ntokens_mistral  \
# 0  Our 10-year-old has been having a tough time a...                     158
# 1  My 14-year-old daughter recently admitted she’...                     159
#
#                            topic  \
# 0  Co-parenting after separation
# 1               Fear of the dark
#
#                                          user_prompt  \
# 0  Dealing with Emotional Outbursts - Our 10-year...
# 1  Teenager Afraid of the Dark: Is This Normal? -...
#
#                               pretendparentai_answer  \
# 0  When they start getting emotional, ask what is...
# 1  The only thing you should worry about is how l...
#
#                               mistralinstruct_answer
# 0  I understand your situation can be challenging...
# 1  It's quite normal for children, even teenagers...

# %%
SYSTEM_PROMPT = """You are an impartial judge.
Your task is to compare two model responses (System A = Mistral Instruct v0.3, System B = PretendParentAI).
PretendParentAI simulates a parent on Reddit and gives advice in that style.

Criteria to evaluate:
1. Helpfulness – Does the response directly address the user’s question and provide useful guidance?
2. Empathy & Tone – Is the response empathetic, warm and supportive?
3. Creativity - Does the response offer creative or unique solutions that cannot be easily found elsewhere?
4. Clarity – Is the response easy to follow and well-structured?
5. Relatability – Is the style conversational and human-like, making the advice easier to relate to, rather than mechanical?
6. Adoptability – How likely is the user to adopt and act on the advice in the response?

Output:
- For each of the 6 criteria above, pick a which system 'won' (is better than the other) or if there's a tie: System A, System B, or Tie.
- Assign an overall winner: System A, System B, or Tie. Try your best to always pick a winner.
- Justify your reasoning for the above in a few words.

Your evaluation should be formatted as:
{{
  "winner_helpfulness": "<string>",
  "winner_empathy_tone": "<string>",
  "winner_creativity": "<string>",
  "winner_clarity": "<string>",
  "winner_relatability": "<string>",
  "winner_adoptability": "<string>",
  "winner_overall": "<string>",
  "justification": "<string>",
}}
"""

USER_PROMPT = """User's Prompt: 
{user_prompt}

System A (Mistral Instruct v0.3) Response:
{mistral_response}

System B (PretendParentAI) Response:
{pretendparentai_response}
"""

# %%
client = OpenAI(api_key=OPENAI_KEY)

evaluations = []
for i in range(len(test_all_df)):
    user_prompt_formatted = USER_PROMPT.format(
        user_prompt = test_all_df["user_prompt"].iloc[i],
        mistral_response = test_all_df["mistralinstruct_answer"].iloc[i],
        pretendparentai_response = test_all_df["pretendparentai_answer"].iloc[i]
    )
    resp = client.responses.create(
        model=MODEL_NAME,
        temperature=MODEL_TEMPERATURE,
        instructions=SYSTEM_PROMPT,
        input=user_prompt_formatted,
        text={
            "format": {
                "type": "json_schema",
                "name": "eval",
                "strict": True,
                "schema": {
                    "type": "object",
                        "properties": {
                            "winner_helpfulness": {
                                "type": "string",
                                "enum": ["System A", "System B", "Tie"],
                                "description": "Which system's response is more helpful?"
                            },
                            "winner_empathy_tone": {
                                "type": "string",
                                "enum": ["System A", "System B", "Tie"],
                                "description": "Which system's response is more empathetic, warm, and supportive?"
                            },
                            "winner_creativity": {
                                "type": "string",
                                "enum": ["System A", "System B", "Tie"],
                                "description": "Which system's response is more creative or unique i.e. not easily found elsewhere?"
                            },
                            "winner_clarity": {
                                "type": "string",
                                "enum": ["System A", "System B", "Tie"],
                                "description": "Which system's response is easier to follow and better structured?"
                            },
                            "winner_relatability": {
                                "type": "string",
                                "enum": ["System A", "System B", "Tie"],
                                "description": "Which system's response sounds more conversational, human-like, and relatable?"
                            },
                            "winner_adoptability": {
                                "type": "string",
                                "enum": ["System A", "System B", "Tie"],
                                "description": "Which response is the user most likely to adopt and act on?"
                            },
                            "winner_overall": {
                                "type": "string",
                                "enum": ["System A", "System B", "Tie"],
                                "description": "Which system's response was better overall?"
                            },
                            "justification": {
                                "type": "string",
                                "description": "Justify your reasoning for the above decisions in a few words."
                            },
                        },
                    "required": [
                        "winner_helpfulness",
                        "winner_empathy_tone",
                        "winner_creativity",
                        "winner_clarity",
                        "winner_relatability",
                        "winner_adoptability",
                        "winner_overall",
                        "justification"
                    ],
                    "additionalProperties": False
                }
            }
        }
    )
    parsed = json.loads(resp.output_text)
    parsed["id"] = test_all_df["id"].iloc[i]
    print (f"{parsed['id']} {parsed['winner_overall']}: {parsed['justification']}")
    evaluations.append(parsed)
# Out:
# 1 System B: System B provides a more empathetic and relatable response, focusing on listening and understanding, which is crucial for emotional support. It offers clear, actionable advice and explains the situation in a way a child might understand, making it more likely to be adopted by the user.
# 2 System A: System A provides a more comprehensive and structured response, addressing the issue with empathy and offering practical solutions. It explains the fear and suggests ways to help the daughter feel safer. System B is more conversational and relatable but lacks depth and structure. Overall, System A's response is more likely to be adopted due to its clarity and helpfulness.
# 3 System A: System A provides a structured, gentle approach with steps that are easy to follow, making it more helpful and adoptable. It uses empathetic language, offering comfort and understanding. System B is more straightforward and relatable but lacks the warmth and structure needed for such a sensitive topic.
# 4 System A: System A provides structured, practical tips directly addressing the user's needs, making it more helpful and adoptable. System B offers a more empathetic and relatable tone, acknowledging the challenges and suggesting creative solutions. However, System A's clarity and directness make it the overall winner.
# 5 System A: System A provides a structured approach to aligning discipline methods, which directly addresses the user's concern about mixed messages. System B offers a personal anecdote, which is empathetic and relatable but less directly applicable. System A's clarity and structured advice make it more adoptable, while System B's tone is warmer and more creative.
# 6 System A: System A provides a more comprehensive and structured response, addressing flexibility, budget concerns, and community resources. System B is more empathetic and relatable but lacks depth. System A's advice is more likely to be adopted due to its practical suggestions.
# 7 System B: System A provides structured strategies, making it more helpful and clear. However, System B offers a more empathetic, relatable, and conversational tone, which is likely to be more comforting and adoptable for the user. Overall, System B's response feels more supportive and human-like.
# 8 System A: System A provides a structured list of apps and strategies, making it more helpful and clear. System B is more empathetic and relatable with a personal touch, but System A's advice is more likely to be adopted due to its directness and specificity.
# 9 System A: System A provides structured, actionable strategies directly addressing the issue, making it more helpful and adoptable. System B offers a more empathetic and relatable tone but lacks specific guidance. System A's suggestions are creative and clear, while System B's advice is more general.
# 10 System A: System A provides practical, structured advice with a supportive tone, making it more helpful and adoptable. System B attempts humor but lacks clear guidance and empathy, though it is more relatable in style.
# 11 System A: System A provides a structured and clear response with practical advice on bedtime routines and addressing anxiety. System B offers creative suggestions like a weighted blanket but lacks structure and clarity. System B's tone is more empathetic and relatable, but System A's advice is more likely to be adopted.
# 12 System A: System A provides structured, empathetic, and clear advice with practical steps like empathy and active listening. System B is more relatable but less structured and lacks empathy. System A's approach is more likely to be adopted due to its clarity and supportive tone.
# 13 System A: System A provides clear, actionable advice on how to approach the topic with a child, using simple language and emphasizing the importance of memories. System B shares a personal story, which is relatable but lacks direct guidance. System A's response is more structured and empathetic, making it more likely to be adopted.
# 14 System A: System A provides practical, structured strategies for sharing toys, making it more helpful and adoptable. It maintains a supportive tone and offers creative solutions like toy rotation and turn-taking. System B's response is more relatable in style but lacks practical advice and empathy, focusing on a punitive approach.
# 15 System A: System A provides a balanced, structured response with clear guidance and encouragement, making it more helpful and adoptable. It also maintains a warm, supportive tone. System B is more relatable and conversational but less structured. Both offer similar creative ideas, but System A's clarity and empathy give it the edge overall.
# 16 System A: System A provides structured, practical tips and addresses the specific issue of noise with actionable advice. System B is more empathetic and relatable, sharing personal experience, but lacks detailed guidance. System A's advice is more likely to be adopted due to its clarity and specificity.
# 17 System A: System A provides direct, actionable advice tailored to the user's situation, making it more helpful and adoptable. It maintains a clear and empathetic tone. System B offers a personal anecdote, which is relatable and creative, but less directly applicable to the user's needs.
# 18 System A: System A provides structured, specific suggestions like joining community groups and engaging with schools, making it more helpful and adoptable. System B is warmer and more conversational, enhancing relatability and empathy. However, System A's clarity and detailed advice make it the overall winner.
# 19 System B: System A provides structured strategies and creative solutions, making it helpful and clear. However, System B offers a personal anecdote, making it more empathetic, relatable, and likely to be adopted by the user. Overall, System B's approach is more engaging and supportive.
# 20 System B: System A provides structured advice and clear steps, making it more helpful and clear. System B, however, offers a more empathetic and relatable tone, making it feel warmer and more supportive. System B's advice is more likely to be adopted due to its conversational style and focus on emotional reassurance.
# 21 System A: System A provides a structured and detailed approach with multiple strategies, making it more helpful and adoptable. It also maintains a warm and empathetic tone. System B is more relatable and conversational but lacks depth and clarity in advice.
# 22 System A: System A provides structured conversation starters and focuses on understanding friendship dynamics, making it more helpful and clear. System B is more empathetic and relatable, focusing on emotional support. However, System A's advice is more actionable and likely to be adopted.
# 23 System A: System A provides structured, practical advice with empathy and clarity, making it more helpful and adoptable. System B's response is more rigid and lacks warmth, making it less relatable and supportive.
# 24 System B: System B provides a more comprehensive and empathetic response, offering personal experience and suggesting therapy, which is creative and relatable. It is structured in a conversational tone, making it easier to adopt.
# 25 System A: System A provides structured, practical strategies like backup snacks and meal prep involvement, making it more helpful and adoptable. System B is more empathetic and relatable with a conversational tone, but lacks detailed guidance. System A's clarity and creativity in offering specific solutions make it the overall winner.
# 26 System B: System A provides structured advice and a clear explanation of the sleep regression, making it helpful and clear. However, System B offers a more empathetic, relatable, and conversational tone, sharing personal experiences and practical tips like taking shifts and using white noise. This makes System B's response more adoptable and creative, as it includes personal anecdotes and a supportive tone.
# 27 System A: System A provides structured, actionable advice with clear steps, making it more helpful and adoptable. System B is more empathetic and relatable, offering a conversational tone and creative suggestions. However, System A's clarity and direct guidance make it the overall winner.
# 28 System B: System B provides a more comprehensive and empathetic response, addressing the user's emotional state and offering practical advice like therapy and sleep adjustments. It is more conversational and relatable, making it easier for the user to adopt the suggestions.
# 29 System A: System A provides a structured list of strategies, making it more helpful and clear. It also offers creative solutions like finding a quiet space. System B is more empathetic and relatable, using a conversational tone. However, System A's advice is more likely to be adopted due to its practical and varied suggestions.
# 30 System A: System A provides specific book recommendations directly addressing the user's request, making it more helpful and adoptable. It also maintains a clear and empathetic tone. System B offers a creative approach with additional activities but lacks direct book suggestions and clarity. System B's conversational style is more relatable, but overall, System A is more effective in addressing the user's needs.
# 31 System A: System A provides structured, practical steps that directly address the issue without confrontation. System B offers a unique perspective on cultural attitudes towards healthy eating, which is creative but less directly actionable. System A's clarity and adoptability make it more helpful overall, while System B's tone is more empathetic and relatable.
# 32 System A: System A provides structured, practical advice directly addressing the user's need for self-care. It is empathetic and clear, making it more likely to be adopted. System B offers a creative solution but lacks broader applicability and empathy.
# 33 System B: System A provides structured advice with clear steps, making it helpful and clear. However, System B offers a more empathetic and relatable tone, addressing the emotional aspect of sharing. It also suggests creative ways to handle the situation, making it more likely for the user to adopt the advice.
# 34 System A: System A provides structured, age-appropriate strategies directly addressing the user's challenge, making it more helpful and adoptable. System B offers a more empathetic and relatable tone with creative suggestions like personalized cases, but lacks direct strategies for managing screen time. Overall, System A's response is more practical and actionable.
# 35 System A: System A provides clear, structured advice with specific, age-appropriate chores and tips on implementation, making it more helpful and adoptable. System B offers a more empathetic and relatable tone, sharing personal experiences, but lacks specific guidance. System A's response is more creative with its visual suggestion, and overall, it is clearer and more actionable.
# 36 System B: System A provides structured advice but lacks warmth. System B offers empathetic, relatable, and creative solutions, making it more likely to be adopted by the user.
# 37 System A: System A provides structured, actionable advice with clear steps, making it more helpful and adoptable. System B is more empathetic and relatable, offering a warm tone. Both responses are equally creative, but System A's clarity gives it the edge overall.
# 38 System A: System A provides practical strategies tailored to the user's situation, emphasizing preparation and inclusion. It is empathetic and supportive, offering creative solutions like involving the child in exploring new foods. The response is clear, structured, and relatable, making it more likely for the user to adopt the advice. System B's approach is more rigid and less empathetic, focusing on a single strategy without addressing the user's concerns about family gatherings.
# 39 System B: System A provides structured tips, making it helpful and clear. However, System B offers a more empathetic, relatable, and creative approach, addressing emotional aspects and adaptability, which is likely more adoptable by the user.
# 40 System A: System A provides a direct and practical response addressing potential causes and solutions for the sleep issue, making it more helpful and adoptable. System B offers a more empathetic and creative response with a unique perspective, but lacks direct applicability to the sleep problem. System A's clarity and focus on the specific issue make it the overall winner.
# 41 System B: System A provides structured, practical advice, making it more helpful and clear. However, System B offers a unique, empathetic approach with a personal touch, making it more relatable and adoptable. Overall, System B's response is more engaging and supportive.
# 42 System B: System A provides structured advice, but System B offers personal anecdotes and creative solutions, making it more relatable and empathetic. System B's conversational tone and practical tips are likely to be more adoptable by the user.
# 43 System A: System A provides structured, practical advice with empathy and clarity, making it more helpful and adoptable. System B offers a personal anecdote, which is relatable but less practical and empathetic.
# 44 System A: System A provides structured advice with actionable steps, making it more helpful and adoptable. System B offers a more empathetic and relatable tone, sharing personal experiences, which adds creativity. However, System A's clarity and practical guidance make it the overall winner.
# 45 System A: System A provides a structured list of creative activities with clear explanations, making it more helpful and adoptable. It also maintains a warm and supportive tone. System B is more relatable and conversational but lacks depth and clarity in suggestions.
# 46 System A: System A provides a detailed explanation of teenage sleep patterns and offers practical solutions, making it more helpful and adoptable. System B is more empathetic and relatable, using personal anecdotes, but lacks specific guidance. System A's structured advice and clarity make it the overall winner.
# 47 System A: System A provides structured advice on establishing rules and compromising, which directly addresses the user's question. It is empathetic and supportive, offering practical steps. System B is more relatable and conversational but lacks specific guidance. Overall, System A's response is more helpful and actionable.
# 48 System A: System A provides structured, actionable advice with clear steps, making it more helpful and adoptable. System B offers a more empathetic and relatable tone, with creative suggestions for alternative activities. However, System A's clarity and direct guidance make it the overall winner.
# 49 System B: System B provides practical, relatable advice with a warm tone, offering specific actions and considerations. It addresses the issue directly and creatively suggests monitoring media exposure, making it more likely to be adopted.
# 50 System A: System A provides practical advice on meal planning and involves the child in the process, making it more helpful and adoptable. System B shares a personal story, which is relatable and empathetic, but lacks actionable guidance. System A's response is clearer and more structured, while System B's tone is warmer and more conversational.
# 51 System A: System A provides structured, practical strategies directly addressing the issue, making it more helpful and adoptable. System B offers a personal anecdote, which is relatable and empathetic, but less structured and clear. System A's response is more creative with specific strategies, while System B's tone is warmer and more conversational.
# 52 System A: System A provides structured, actionable advice directly addressing the user's question, making it more helpful and adoptable. System B offers a more empathetic and relatable tone, sharing personal experiences, which adds creativity. However, System A's clarity and focus on practical steps make it the overall winner.
# 53 System A: System A provides structured advice on sleep regression with practical strategies, making it more helpful and adoptable. System B offers a more empathetic and relatable tone, with creative suggestions, but lacks the structured guidance found in System A.
# 54 System B: System B provides a more comprehensive and practical approach to social skills, emphasizing real-world interactions and manners. It is more empathetic and relatable, using a conversational tone that feels supportive. System A offers a structured list but lacks depth and warmth. System B's advice is more likely to be adopted due to its practical nature and relatable style.
# 55 System A: System A provides structured, practical strategies and maintains a supportive tone, making it more helpful and adoptable. System B is more relatable with its conversational style but lacks empathy and clarity. System A's advice is more likely to be adopted due to its constructive approach.
# 56 System A: System A provides a broader range of practical suggestions, making it more helpful and adoptable. It also offers creative ideas like volunteering and DIY crafts. System B is more empathetic and relatable, focusing on maintaining family connections through calls, but System A's structured approach and variety make it the overall winner.
# 57 System A: System A provides structured, practical advice with empathy and clarity, making it more helpful and adoptable. System B is more relatable in tone but lacks detailed guidance.
# 58 System A: System A provides structured strategies that directly address the user's question, making it more helpful and adoptable. It offers creative solutions like teaching emotional intelligence. System B is more empathetic and relatable, using a conversational tone, but lacks specific strategies. Overall, System A's response is clearer and more actionable.
# 59 System A: System A provides structured, practical tips directly addressing the question, making it more helpful and adoptable. It also offers creative ideas like using cookie cutters. System B is more empathetic and relatable, with a conversational tone, but lacks specific healthy meal suggestions.
# 60 System B: System A provides structured strategies, but System B offers a creative, relatable activity with a warm tone. System B's approach is more likely to be adopted due to its practical example and engaging style.
# 61 System B: System B provides practical, creative solutions and shares personal experience, making it more relatable and adoptable. System A is clear and structured but less detailed in practical advice.
# 62 System B: System A provides structured advice with specific strategies, making it more helpful and creative. However, System B offers a more empathetic, relatable, and conversational tone, making it easier to adopt and follow. Overall, System B's approach is more supportive and likely to resonate with the user.
# 63 System A: System A provides specific, creative solutions directly addressing the fear of the dark, making it more helpful and adoptable. System B is more empathetic and relatable, offering a comforting tone, but lacks specific creative solutions. System A's clarity and structured approach make it easier to follow.
# 64 System A: System A provides structured advice with steps for communication and compromise, making it more helpful and adoptable. It also maintains a warm tone. System B is more relatable and conversational but lacks structure and depth.
# 65 System A: System A provides structured, practical strategies directly addressing the issue, making it more helpful and adoptable. System B is more empathetic and relatable with a conversational tone and creative storytelling idea, but lacks detailed guidance. Overall, System A offers clearer, actionable advice.
# 66 System A: System A provides structured, practical strategies for managing picky eating, making it more helpful and adoptable. It also offers creative ideas like making mealtime fun. System B is more relatable with a casual tone but lacks detailed guidance. Overall, System A is more comprehensive and supportive.
# 67 System B: System A provides structured strategies, making it helpful and clear. However, System B offers a more empathetic, relatable, and creative approach, encouraging open dialogue and negotiation with teens. This makes System B's advice more adoptable and supportive.
# 68 System A: System A provides structured, practical strategies directly addressing the issue, making it more helpful and adoptable. System B offers a more empathetic and relatable tone with creative personal insights, but lacks clarity and comprehensive guidance.
# 69 System A: System A provides structured strategies with clear steps, focusing on empathy and boundary-setting, which are helpful and adoptable. System B offers a more conversational tone but lacks structure and clarity. System A's approach is more likely to be adopted due to its clear guidance.
# 70 System A: System A provides structured strategies directly addressing the user's concerns, making it more helpful and adoptable. System B offers a personal story, which is empathetic and relatable, but less structured. System A's clarity and actionable advice make it the overall winner.
# 71 System A: System A provides practical steps for emergency preparedness, making it more helpful and adoptable. System B offers empathy and relatability with a conversational tone, but lacks direct advice. System A's structured response is clearer, while System B's creativity lies in suggesting community connections.
# 72 System A: System A provides a balanced approach to discipline, offering practical advice on combining methods, which is directly helpful. System B shows more empathy and creativity by suggesting counseling, but lacks clarity and structure. System A's advice is more likely to be adopted due to its clear and actionable nature.
# 73 System A: System A provides a more comprehensive and structured response, addressing both layout and safety with specific suggestions. It is empathetic and supportive, offering practical advice like guardrails and non-slip rugs. System B is more conversational and relatable but lacks depth and clarity. System A's advice is more likely to be adopted due to its thoroughness.
# 74 System A: System A provides structured, practical advice directly addressing the user's concerns, with empathy and clarity. System B offers a relatable tone but lacks specific guidance. Overall, System A's response is more actionable and supportive.
# 75 System A: System A provides structured strategies and practical advice, making it more helpful and adoptable. It also offers creative solutions like involving children in decisions. System B is more empathetic and relatable, with a warm tone, but lacks specific strategies. Overall, System A's clarity and actionable advice make it the better choice.
# 76 System A: System A provides a structured approach with multiple strategies, making it more helpful and adoptable. System B offers a unique and creative solution with the egg timer, and its tone is more empathetic and relatable. However, System A's clarity and comprehensive advice make it the overall winner.
# 77 System B: System B provides practical, detailed advice with empathy and personal experience, making it more relatable and adoptable. It offers creative solutions like using Care.com and emphasizes self-care, making it clearer and more helpful.
# 78 System A: System A provides structured, actionable advice with clear steps, making it more helpful and adoptable. It also maintains a warm and supportive tone. System B is more conversational and relatable but lacks specific guidance and structure.
# 79 System B: System A provides a structured approach, which is helpful, but System B offers a more relatable and empathetic response. System B's suggestion of a flexible chart is creative and likely more adoptable by the user. System A is clearer, but System B's conversational tone makes it more engaging and supportive.
# 80 System A: System A provides structured, creative ideas directly addressing the prompt, making it more helpful and adoptable. System B is warmer and more relatable but less focused on the specific request for creative ideas.
# 81 System A: System A provides structured, empathetic advice with clear steps, making it more helpful and adoptable. System B offers a creative, relatable approach but lacks depth and clarity. Overall, System A's response is more comprehensive and supportive.
# 82 System A: System A provides structured, practical advice on co-parenting during holidays, addressing the user's situation directly. System B offers a personal anecdote, which is empathetic and relatable but less applicable to the user's specific needs. System A's response is clearer and more likely to be adopted due to its actionable suggestions.
# 83 System B: System A provides structured advice but lacks completion and personal touch. System B offers relatable, empathetic, and creative solutions based on personal experience, making it more adoptable and supportive.
# 84 System B: System B provides practical, specific advice on managing screen time, including using a timer and considering a laptop for better focus. It offers a more empathetic and relatable tone, acknowledging the effort required from the parent. The response is clear, structured, and likely to be adopted by the user.
# 85 System A: System A provides a more structured and clear response, directly addressing the user's concerns with practical advice. System B offers a more empathetic and relatable tone, sharing personal experiences, which adds creativity. However, System A's advice is more likely to be adopted due to its clarity and directness.
# 86 System A: System A provides a structured list of practical suggestions, making it more helpful and adoptable. System B is more empathetic and relatable, with a conversational tone and creative ideas. However, System A's clarity and direct guidance make it the overall winner.
# 87 System B: System A provides a structured list of strategies, which is helpful and empathetic. However, System B offers a more relatable, conversational, and creative approach with a specific routine, making it easier for the user to adopt and act on.
# 88 System B: System B provides specific, actionable advice with a warm and supportive tone. It suggests creative ways to involve the child, enhancing relatability and adoptability. System A offers general advice but lacks the depth and empathy found in System B's response.
# 89 System A: System A provides a balanced, practical approach with clear steps and reassurance, making it more helpful and adoptable. It also maintains a warm tone. System B is more relatable and conversational but suggests staying until the child stops crying, which may not be practical or advisable. Overall, System A offers a more structured and feasible solution.
# 90 System A: System A provides a structured list of actionable tips directly addressing the user's question, making it more helpful and clear. System B offers a more empathetic and relatable tone, sharing personal experiences, which adds creativity. However, System A's advice is more likely to be adopted due to its clarity and directness.
# 91 System B: System A provides a clear list of chores, making it helpful and clear. However, System B offers a more empathetic and relatable response, sharing personal experiences and emphasizing gradual responsibility and rewards, which enhances adoptability and creativity.
# 92 System A: System A provides a structured, age-appropriate approach with steps to guide the conversation, making it more helpful, clear, and adoptable. It also shows empathy by validating emotions. System B is more relatable with a conversational tone but lacks structure and depth.
# 93 System A: System A provides a structured approach with empathy, self-reflection, and problem-solving, making it more helpful and adoptable. It is clear and supportive, whereas System B offers a more conversational tone but lacks structure and actionable advice.
# 94 System B: System B provides personal insight and a unique perspective, making it more relatable and empathetic. It suggests involving a therapist, adding creativity to the advice. System A is clear and structured but lacks the personal touch and depth of System B.
# 95 System A: System A provides structured, practical strategies directly addressing the issue, making it more helpful and adoptable. System B offers a personal anecdote, which is empathetic and relatable, but less structured and clear. System A's advice is more likely to be adopted due to its clarity and directness.
# 96 System A: System A provides a structured approach with clear steps and emphasizes consistency and communication, making it more helpful and adoptable. System B is more empathetic and relatable, sharing personal experiences, but lacks the structured guidance of System A.
# 97 System A: System A provides a balanced approach, offering both straightforward language and gentle metaphors, which is helpful and empathetic. It is clear and structured, making it easy to follow. System B is more relatable in tone but lacks the nuanced guidance needed for a sensitive topic. Overall, System A's response is more likely to be adopted due to its thoughtful consideration of the child's emotional capacity.
# 98 System A: System A provides practical advice on how to introduce new flavors and addresses nutritional concerns, making it more helpful and adoptable. System B is more empathetic and relatable with personal anecdotes, but lacks specific guidance. System A is clearer and more structured, while System B's tone is warmer and more conversational.
# 99 System B: System A provides structured advice with clear steps, making it helpful and clear. However, System B offers a more empathetic and relatable tone, suggesting creative ideas like using music to make chores fun. System B's conversational style and focus on positive reinforcement make its advice more adoptable.
# 100 System B: System A provides structured and practical advice, but System B offers a creative and relatable solution with a warm tone, making it more likely to be adopted by the user.

# %%
eval_df = pd.DataFrame(evaluations)

# %%
eval_df.to_csv(os.path.join(SHARED_DATA_FOLDER, "pretendparentai_gpt_as_judge_output.csv"))

# %%
norm_counts = pd.concat(
    {col: eval_df[col].value_counts(normalize=True) 
     for col in eval_df.columns if col not in ["justification", "id"]},
    axis=1
).fillna(0)

# %%
norm_counts
# Out:
#           winner_helpfulness  winner_empathy_tone  winner_creativity  \
# System A                 0.9                  0.3               0.47
# System B                 0.1                  0.7               0.48
# Tie                      0.0                  0.0               0.05
#
#           winner_clarity  winner_relatability  winner_adoptability  \
# System A             0.9                 0.02                 0.72
# System B             0.1                 0.98                 0.28
# Tie                  0.0                 0.00                 0.00
#
#           winner_overall
# System A            0.72
# System B            0.28
# Tie                 0.00

# %%
eval_df[["winner_adoptability", "winner_empathy_tone"]].value_counts(normalize=True)
# Out:
# winner_adoptability  winner_empathy_tone
# System A             System B               0.43
#                      System A               0.29
# System B             System B               0.27
#                      System A               0.01
# Name: proportion, dtype: float64
